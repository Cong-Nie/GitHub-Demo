# %% [markdown]
# # Assignment 4
# ## Question 2 - Workforce Planning

# %%
from pulp import *
import pandas as pd

# %%
prob2 = LpProblem('Prob2', LpMinimize)
month = [1, 2, 3, 4, 5, 6]

Initial = 145
Demand_per = [100,100,115,125,140,150] 

# Create a dictionary for Demand_per_mon
Demand_per_mon= makeDict([month], Demand_per) 
print(Demand_per_mon)
# Out:
# {1: 100, 2: 100, 3: 115, 4: 125, 5: 140, 6: 150}

# %%
# ============================
# Define Decision Variables
# ============================
Trained = LpVariable.dicts('Training Decision', month,lowBound = 0, cat = 'Continuous')
Layoff = LpVariable.dicts('Layoff Decision', month, lowBound = 0, cat = 'Continuous')
Num =  LpVariable.dicts('Number of Employees for each month', month, lowBound = 0, cat = 'Continuous')
print(Trained)
print(Layoff)
print(Num)
# Out:
# {1: Training_Decision_1, 2: Training_Decision_2, 3: Training_Decision_3, 4: Training_Decision_4, 5: Training_Decision_5, 6: Training_Decision_6}
# {1: Layoff_Decision_1, 2: Layoff_Decision_2, 3: Layoff_Decision_3, 4: Layoff_Decision_4, 5: Layoff_Decision_5, 6: Layoff_Decision_6}
# {1: Number_of_Employees_for_each_month_1, 2: Number_of_Employees_for_each_month_2, 3: Number_of_Employees_for_each_month_3, 4: Number_of_Employees_for_each_month_4, 5: Number_of_Employees_for_each_month_5, 6: Number_of_Employees_for_each_month_6}

# %%
# ===========================
# Define Objective Function
# ===========================
prob2 += lpSum([(6-i)*3300*0.9*Trained[i] for i in month[0:5]])\
      + 3000*Num[1]\
      + lpSum([3000*(Num[i] - sum(0.9*Trained[j] for j in month[0:i-1])) for i in month[1:6]])
prob2
# Out:
# Prob2:
# MINIMIZE
# 3000*Number_of_Employees_for_each_month_1 + 3000*Number_of_Employees_for_each_month_2 + 3000*Number_of_Employees_for_each_month_3 + 3000*Number_of_Employees_for_each_month_4 + 3000*Number_of_Employees_for_each_month_5 + 3000*Number_of_Employees_for_each_month_6 + 1350.0*Training_Decision_1 + 1080.0*Training_Decision_2 + 810.0*Training_Decision_3 + 540.0*Training_Decision_4 + 270.0*Training_Decision_5 + 0.0
# VARIABLES
# Number_of_Employees_for_each_month_1 Continuous
# Number_of_Employees_for_each_month_2 Continuous
# Number_of_Employees_for_each_month_3 Continuous
# Number_of_Employees_for_each_month_4 Continuous
# Number_of_Employees_for_each_month_5 Continuous
# Number_of_Employees_for_each_month_6 Continuous
# Training_Decision_1 Continuous
# Training_Decision_2 Continuous
# Training_Decision_3 Continuous
# Training_Decision_4 Continuous
# Training_Decision_5 Continuous

# %%
# ===============================================================================
# Define Constraints: Labor Demand, Monthly Employment Limits, Training limits
# ===============================================================================
prob2 += Num[1] == 145
prob2 += Num[1] - Trained[1] >= 100,'Labor demand month 1'
prob2 += Num[6] + 0.2*0.9*(sum(Trained[j] for j in month[0:5])) >= Demand_per_mon[6],'Labor demand month 6'
for i in month[1:5]:
    prob2 += Num[i] - Trained[i] + 0.2*0.9*(sum(Trained[j] for j in month[0:i-1])) >= Demand_per_mon[i],'Labor demand month %s'%i

# Next month’s total employment = reduce the layoff amount 
for i in month[0:5]:
    prob2 += Num[i] - Layoff[i] == Num[i+1],'Inflow-outflow balance %s'%i
    
# Each month‘s layoff = 5% of (total employees - trained programmers - programmers on training)
prob2 += Layoff[1] == 0.05*(Num[1] - Trained[1]),'Layoff month 1'
for i in month[1:5]:
     prob2 += Layoff[i] == 0.05*(Num[i] - sum(Trained[j] for j in month[0:i])),'Layoff month %s'%i
prob2 += Layoff[6] == 0.05*(Num[6] - Trained[1] - Trained[2] - Trained[3] - Trained[4] - Trained[5]),'Layoff month 6'

    
# Each month’s # of trained programmers <= # of untrained programmers
for i in month[1:5]:
      prob2 += Trained[i] <= Num[i] - sum(Trained[j] for j in month[0:i-1]),'Train limit month %s'%i
prob2 += Trained[1] <= Num[1],'Train limit month 1'
prob2
# Out:
# Prob2:
# MINIMIZE
# 3000*Number_of_Employees_for_each_month_1 + 3000*Number_of_Employees_for_each_month_2 + 3000*Number_of_Employees_for_each_month_3 + 3000*Number_of_Employees_for_each_month_4 + 3000*Number_of_Employees_for_each_month_5 + 3000*Number_of_Employees_for_each_month_6 + 1350.0*Training_Decision_1 + 1080.0*Training_Decision_2 + 810.0*Training_Decision_3 + 540.0*Training_Decision_4 + 270.0*Training_Decision_5 + 0.0
# SUBJECT TO
# _C1: Number_of_Employees_for_each_month_1 = 145
#
# Labor_demand_month_1: Number_of_Employees_for_each_month_1
#  - Training_Decision_1 >= 100
#
# Labor_demand_month_6: Number_of_Employees_for_each_month_6
#  + 0.18 Training_Decision_1 + 0.18 Training_Decision_2
#  + 0.18 Training_Decision_3 + 0.18 Training_Decision_4
#  + 0.18 Training_Decision_5 >= 150
#
# Labor_demand_month_2: Number_of_Employees_for_each_month_2
#  + 0.18 Training_Decision_1 - Training_Decision_2 >= 100
#
# Labor_demand_month_3: Number_of_Employees_for_each_month_3
#  + 0.18 Training_Decision_1 + 0.18 Training_Decision_2 - Training_Decision_3
#  >= 115
#
# Labor_demand_month_4: Number_of_Employees_for_each_month_4
#  + 0.18 Training_Decision_1 + 0.18 Training_Decision_2
#  + 0.18 Training_Decision_3 - Training_Decision_4 >= 125
#
# Labor_demand_month_5: Number_of_Employees_for_each_month_5
#  + 0.18 Training_Decision_1 + 0.18 Training_Decision_2
#  + 0.18 Training_Decision_3 + 0.18 Training_Decision_4 - Training_Decision_5
#  >= 140
#
# Inflow_outflow_balance_1: - Layoff_Decision_1
#  + Number_of_Employees_for_each_month_1 - Number_of_Employees_for_each_month_2
#  = 0
#
# Inflow_outflow_balance_2: - Layoff_Decision_2
#  + Number_of_Employees_for_each_month_2 - Number_of_Employees_for_each_month_3
#  = 0
#
# Inflow_outflow_balance_3: - Layoff_Decision_3
#  + Number_of_Employees_for_each_month_3 - Number_of_Employees_for_each_month_4
#  = 0
#
# Inflow_outflow_balance_4: - Layoff_Decision_4
#  + Number_of_Employees_for_each_month_4 - Number_of_Employees_for_each_month_5
#  = 0
#
# Inflow_outflow_balance_5: - Layoff_Decision_5
#  + Number_of_Employees_for_each_month_5 - Number_of_Employees_for_each_month_6
#  = 0
#
# Layoff_month_1: Layoff_Decision_1 - 0.05 Number_of_Employees_for_each_month_1
#  + 0.05 Training_Decision_1 = 0
#
# Layoff_month_2: Layoff_Decision_2 - 0.05 Number_of_Employees_for_each_month_2
#  + 0.05 Training_Decision_1 + 0.05 Training_Decision_2 = 0
#
# Layoff_month_3: Layoff_Decision_3 - 0.05 Number_of_Employees_for_each_month_3
#  + 0.05 Training_Decision_1 + 0.05 Training_Decision_2
#  + 0.05 Training_Decision_3 = 0
#
# Layoff_month_4: Layoff_Decision_4 - 0.05 Number_of_Employees_for_each_month_4
#  + 0.05 Training_Decision_1 + 0.05 Training_Decision_2
#  + 0.05 Training_Decision_3 + 0.05 Training_Decision_4 = 0
#
# Layoff_month_5: Layoff_Decision_5 - 0.05 Number_of_Employees_for_each_month_5
#  + 0.05 Training_Decision_1 + 0.05 Training_Decision_2
#  + 0.05 Training_Decision_3 + 0.05 Training_Decision_4
#  + 0.05 Training_Decision_5 = 0
#
# Layoff_month_6: Layoff_Decision_6 - 0.05 Number_of_Employees_for_each_month_6
#  + 0.05 Training_Decision_1 + 0.05 Training_Decision_2
#  + 0.05 Training_Decision_3 + 0.05 Training_Decision_4
#  + 0.05 Training_Decision_5 = 0
#
# Train_limit_month_2: - Number_of_Employees_for_each_month_2
#  + Training_Decision_1 + Training_Decision_2 <= 0
#
# Train_limit_month_3: - Number_of_Employees_for_each_month_3
#  + Training_Decision_1 + Training_Decision_2 + Training_Decision_3 <= 0
#
# Train_limit_month_4: - Number_of_Employees_for_each_month_4
#  + Training_Decision_1 + Training_Decision_2 + Training_Decision_3
#  + Training_Decision_4 <= 0
#
# Train_limit_month_5: - Number_of_Employees_for_each_month_5
#  + Training_Decision_1 + Training_Decision_2 + Training_Decision_3
#  + Training_Decision_4 + Training_Decision_5 <= 0
#
# Train_limit_month_1: - Number_of_Employees_for_each_month_1
#  + Training_Decision_1 <= 0
#
# VARIABLES
# Layoff_Decision_1 Continuous
# Layoff_Decision_2 Continuous
# Layoff_Decision_3 Continuous
# Layoff_Decision_4 Continuous
# Layoff_Decision_5 Continuous
# Layoff_Decision_6 Continuous
# Number_of_Employees_for_each_month_1 Continuous
# Number_of_Employees_for_each_month_2 Continuous
# Number_of_Employees_for_each_month_3 Continuous
# Number_of_Employees_for_each_month_4 Continuous
# Number_of_Employees_for_each_month_5 Continuous
# Number_of_Employees_for_each_month_6 Continuous
# Training_Decision_1 Continuous
# Training_Decision_2 Continuous
# Training_Decision_3 Continuous
# Training_Decision_4 Continuous
# Training_Decision_5 Continuous

# %%
# =========================
# Solving the PULP model
# =========================
prob2.solve()
print("Status:",LpStatus[prob2.status])
# Out:
# Status: Optimal

# %%
# =======================================================
# Print Out the Optimal Solution and Decision Variables
# =======================================================
for i in prob2.variables():
    print(i.name, "=", i.varValue,"\tReduced Cost =", i.dj)
print("The minimize total operating cost for 6 months is ", value(prob2.objective))
# Out:
# Layoff_Decision_1 = 6.5817658 	Reduced Cost = 0.0
# Layoff_Decision_2 = 4.2114837 	Reduced Cost = 4.5474735e-13
# Layoff_Decision_3 = 2.5528749 	Reduced Cost = 2.2737368e-13
# Layoff_Decision_4 = 1.3441942 	Reduced Cost = 0.0
# Layoff_Decision_5 = 0.81857044 	Reduced Cost = 4.5474735e-13
# Layoff_Decision_6 = 0.77764192 	Reduced Cost = 0.0
# Number_of_Employees_for_each_month_1 = 145.0 	Reduced Cost = -1.080025e-12
# Number_of_Employees_for_each_month_2 = 138.41823 	Reduced Cost = 4.5474735e-13
# Number_of_Employees_for_each_month_3 = 134.20675 	Reduced Cost = 9.9475983e-14
# Number_of_Employees_for_each_month_4 = 131.65388 	Reduced Cost = 3.6948222e-13
# Number_of_Employees_for_each_month_5 = 130.30968 	Reduced Cost = -1.4210855e-13
# Number_of_Employees_for_each_month_6 = 129.49111 	Reduced Cost = -9.094947e-13
# Training_Decision_1 = 13.364683 	Reduced Cost = -3.9790393e-13
# Training_Decision_2 = 40.823877 	Reduced Cost = 5.6843419e-14
# Training_Decision_3 = 28.960691 	Reduced Cost = -8.5265128e-13
# Training_Decision_4 = 21.620741 	Reduced Cost = -6.2527761e-13
# Training_Decision_5 = 9.16828 	Reduced Cost = 1.4210855e-13
# The minimize total operating cost for 6 months is  2526979.8546599997

# %%
print("\nSensitivity Analysis\nConstraint\t\t\t\t\t\t\tShadow Price\t\tSlack")
for name,c in list(prob2.constraints.items()):
    print(name,":",c,"\t",c.pi,"\t\t",c.slack)
# Out:
# Sensitivity Analysis
# Constraint							Shadow Price		Slack
# _C1 : Number_of_Employees_for_each_month_1 = 145 	 8440.1369 		 -0.0
# Labor_demand_month_1 : Number_of_Employees_for_each_month_1 - Training_Decision_1 >= 100 	 0.0 		 -31.635320000000007
# Labor_demand_month_6 : Number_of_Employees_for_each_month_6 + 0.18000000000000002*Training_Decision_1 + 0.18000000000000002*Training_Decision_2 + 0.18000000000000002*Training_Decision_3 + 0.18000000000000002*Training_Decision_4 + 0.18000000000000002*Training_Decision_5 >= 150.0 	 6089.6523 		 -0.0
# Labor_demand_month_2 : Number_of_Employees_for_each_month_2 + 0.18000000000000002*Training_Decision_1 - Training_Decision_2 >= 100.0 	 471.46017 		 -0.0
# Labor_demand_month_3 : Number_of_Employees_for_each_month_3 + 0.18000000000000002*Training_Decision_1 + 0.18000000000000002*Training_Decision_2 - Training_Decision_3 >= 115.0 	 770.99301 		 -0.0
# Labor_demand_month_4 : Number_of_Employees_for_each_month_4 + 0.18000000000000002*Training_Decision_1 + 0.18000000000000002*Training_Decision_2 + 0.18000000000000002*Training_Decision_3 - Training_Decision_4 >= 125.0 	 932.92113 		 -0.0
# Labor_demand_month_5 : Number_of_Employees_for_each_month_5 + 0.18000000000000002*Training_Decision_1 + 0.18000000000000002*Training_Decision_2 + 0.18000000000000002*Training_Decision_3 + 0.18000000000000002*Training_Decision_4 - Training_Decision_5 >= 140.0 	 980.62004 		 -0.0
# Inflow_outflow_balance_1 : -Layoff_Decision_1 + Number_of_Employees_for_each_month_1 - Number_of_Employees_for_each_month_2 = 0 	 -5726.4599 		 -0.0
# Inflow_outflow_balance_2 : -Layoff_Decision_2 + Number_of_Employees_for_each_month_2 - Number_of_Employees_for_each_month_3 = 0 	 -3366.2317 		 -0.0
# Inflow_outflow_balance_3 : -Layoff_Decision_3 + Number_of_Employees_for_each_month_3 - Number_of_Employees_for_each_month_4 = 0 	 -1197.0786 		 -0.0
# Inflow_outflow_balance_4 : -Layoff_Decision_4 + Number_of_Employees_for_each_month_4 - Number_of_Employees_for_each_month_5 = 0 	 915.78976 		 -0.0
# Inflow_outflow_balance_5 : -Layoff_Decision_5 + Number_of_Employees_for_each_month_5 - Number_of_Employees_for_each_month_6 = 0 	 3089.6523 		 -0.0
# Layoff_month_1 : Layoff_Decision_1 - 0.05*Number_of_Employees_for_each_month_1 + 0.05*Training_Decision_1 = -0.0 	 -5726.4599 		 -1.110223e-16
# Layoff_month_2 : Layoff_Decision_2 - 0.05*Number_of_Employees_for_each_month_2 + 0.05*Training_Decision_1 + 0.05*Training_Decision_2 = -0.0 	 -3366.2317 		 4.4408921e-16
# Layoff_month_3 : Layoff_Decision_3 - 0.05*Number_of_Employees_for_each_month_3 + 0.05*Training_Decision_1 + 0.05*Training_Decision_2 + 0.05*Training_Decision_3 = -0.0 	 -1197.0786 		 4.8849813e-15
# Layoff_month_4 : Layoff_Decision_4 - 0.05*Number_of_Employees_for_each_month_4 + 0.05*Training_Decision_1 + 0.05*Training_Decision_2 + 0.05*Training_Decision_3 + 0.05*Training_Decision_4 = -0.0 	 915.78976 		 -6.3726802e-14
# Layoff_month_5 : Layoff_Decision_5 - 0.05*Number_of_Employees_for_each_month_5 + 0.05*Training_Decision_1 + 0.05*Training_Decision_2 + 0.05*Training_Decision_3 + 0.05*Training_Decision_4 + 0.05*Training_Decision_5 = -0.0 	 3089.6523 		 -3.1641356e-15
# Layoff_month_6 : Layoff_Decision_6 - 0.05*Number_of_Employees_for_each_month_6 + 0.05*Training_Decision_1 + 0.05*Training_Decision_2 + 0.05*Training_Decision_3 + 0.05*Training_Decision_4 + 0.05*Training_Decision_5 = -0.0 	 0.0 		 -4.9960036e-16
# Train_limit_month_2 : -Number_of_Employees_for_each_month_2 + Training_Decision_1 + Training_Decision_2 <= 0 	 0.0 		 84.229674
# Train_limit_month_3 : -Number_of_Employees_for_each_month_3 + Training_Decision_1 + Training_Decision_2 + Training_Decision_3 <= 0 	 0.0 		 51.057499
# Train_limit_month_4 : -Number_of_Employees_for_each_month_4 + Training_Decision_1 + Training_Decision_2 + Training_Decision_3 + Training_Decision_4 <= 0 	 0.0 		 26.883883
# Train_limit_month_5 : -Number_of_Employees_for_each_month_5 + Training_Decision_1 + Training_Decision_2 + Training_Decision_3 + Training_Decision_4 + Training_Decision_5 <= 0 	 0.0 		 16.371409
# Train_limit_month_1 : -Number_of_Employees_for_each_month_1 + Training_Decision_1 <= 0 	 0.0 		 131.63532

# %%
output=[]
for i in month:
    var_output=[]
    var_output.append(Trained[i].varValue)
    var_output.append(Layoff[i].varValue)
    var_output.append(Num[i].varValue)
  
    output.append(var_output)


#print(output)    
col_names=['Training Decision','Layoff','number of employees']
month_names=['Month 1', 'Month 2', 'Month 3', 'Month 4', 'Month 5', 'Month 6']
output_df = pd.DataFrame(output,index=month_names, columns=col_names)

print("Total cost=", value(prob2.objective))
output_df## Format PuLP Output
# Out:
# Total cost= 2526979.8546599997
#          Training Decision    Layoff  number of employees
# Month 1          13.364683  6.581766            145.00000
# Month 2          40.823877  4.211484            138.41823
# Month 3          28.960691  2.552875            134.20675
# Month 4          21.620741  1.344194            131.65388
# Month 5           9.168280  0.818570            130.30968
# Month 6                NaN  0.777642            129.49111

# %%
output=[]
constraint_name=[]
for name, c in list(prob2.constraints.items()):
    var_output = []
    # print(name)
    constraint_name.append(name)
    var_output.append(str(c))
    var_output.append(c.pi)
    var_output.append(c.slack)
    output.append(var_output)
# print(constraint_name)    
col_names = ["Constraints","Shadow Price","Slack"]
# output_df = pd.DataFrame(output, index=constraint_name, columns=col_names)
output_df = pd.DataFrame(output, index = constraint_name, columns = col_names)
output_df
# Out:
#                                                                 Constraints  \
# _C1                              Number_of_Employees_for_each_month_1 = 145
# Labor_demand_month_1      Number_of_Employees_for_each_month_1 - Trainin...
# Labor_demand_month_6      Number_of_Employees_for_each_month_6 + 0.18000...
# Labor_demand_month_2      Number_of_Employees_for_each_month_2 + 0.18000...
# Labor_demand_month_3      Number_of_Employees_for_each_month_3 + 0.18000...
# Labor_demand_month_4      Number_of_Employees_for_each_month_4 + 0.18000...
# Labor_demand_month_5      Number_of_Employees_for_each_month_5 + 0.18000...
# Inflow_outflow_balance_1  -Layoff_Decision_1 + Number_of_Employees_for_e...
# Inflow_outflow_balance_2  -Layoff_Decision_2 + Number_of_Employees_for_e...
# Inflow_outflow_balance_3  -Layoff_Decision_3 + Number_of_Employees_for_e...
# Inflow_outflow_balance_4  -Layoff_Decision_4 + Number_of_Employees_for_e...
# Inflow_outflow_balance_5  -Layoff_Decision_5 + Number_of_Employees_for_e...
# Layoff_month_1            Layoff_Decision_1 - 0.05*Number_of_Employees_f...
# Layoff_month_2            Layoff_Decision_2 - 0.05*Number_of_Employees_f...
# Layoff_month_3            Layoff_Decision_3 - 0.05*Number_of_Employees_f...
# Layoff_month_4            Layoff_Decision_4 - 0.05*Number_of_Employees_f...
# Layoff_month_5            Layoff_Decision_5 - 0.05*Number_of_Employees_f...
# Layoff_month_6            Layoff_Decision_6 - 0.05*Number_of_Employees_f...
# Train_limit_month_2       -Number_of_Employees_for_each_month_2 + Traini...
# Train_limit_month_3       -Number_of_Employees_for_each_month_3 + Traini...
# Train_limit_month_4       -Number_of_Employees_for_each_month_4 + Traini...
# Train_limit_month_5       -Number_of_Employees_for_each_month_5 + Traini...
# Train_limit_month_1       -Number_of_Employees_for_each_month_1 + Traini...
#
#                           Shadow Price         Slack
# _C1                         8440.13690 -0.000000e+00
# Labor_demand_month_1           0.00000 -3.163532e+01
# Labor_demand_month_6        6089.65230 -0.000000e+00
# Labor_demand_month_2         471.46017 -0.000000e+00
# Labor_demand_month_3         770.99301 -0.000000e+00
# Labor_demand_month_4         932.92113 -0.000000e+00
# Labor_demand_month_5         980.62004 -0.000000e+00
# Inflow_outflow_balance_1   -5726.45990 -0.000000e+00
# Inflow_outflow_balance_2   -3366.23170 -0.000000e+00
# Inflow_outflow_balance_3   -1197.07860 -0.000000e+00
# Inflow_outflow_balance_4     915.78976 -0.000000e+00
# Inflow_outflow_balance_5    3089.65230 -0.000000e+00
# Layoff_month_1             -5726.45990 -1.110223e-16
# Layoff_month_2             -3366.23170  4.440892e-16
# Layoff_month_3             -1197.07860  4.884981e-15
# Layoff_month_4               915.78976 -6.372680e-14
# Layoff_month_5              3089.65230 -3.164136e-15
# Layoff_month_6                 0.00000 -4.996004e-16
# Train_limit_month_2            0.00000  8.422967e+01
# Train_limit_month_3            0.00000  5.105750e+01
# Train_limit_month_4            0.00000  2.688388e+01
# Train_limit_month_5            0.00000  1.637141e+01
# Train_limit_month_1            0.00000  1.316353e+02

# %%
from pulp import *
import pandas as pd

# %%
prob2 = LpProblem('Prob2', LpMinimize)
month = [1, 2, 3, 4, 5, 6]

Initial = 145
Demand_per = [100,100,115,150,140,125] 

# Create a dictionary for Demand_per_mon
Demand_per_mon= makeDict([month], Demand_per) 
print(Demand_per_mon)
# Out:
# {1: 100, 2: 100, 3: 115, 4: 150, 5: 140, 6: 125}

# %%
Trained = LpVariable.dicts('Training Decision', month,lowBound = 0, cat = 'Continuous')
Layoff = LpVariable.dicts('Layoff Decision', month, lowBound = 0, cat = 'Continuous')
Num =  LpVariable.dicts('Number of Employees for each month', month, lowBound = 0, cat = 'Continuous')
print(Trained)
print(Layoff)
print(Num)
# Out:
# {1: Training_Decision_1, 2: Training_Decision_2, 3: Training_Decision_3, 4: Training_Decision_4, 5: Training_Decision_5, 6: Training_Decision_6}
# {1: Layoff_Decision_1, 2: Layoff_Decision_2, 3: Layoff_Decision_3, 4: Layoff_Decision_4, 5: Layoff_Decision_5, 6: Layoff_Decision_6}
# {1: Number_of_Employees_for_each_month_1, 2: Number_of_Employees_for_each_month_2, 3: Number_of_Employees_for_each_month_3, 4: Number_of_Employees_for_each_month_4, 5: Number_of_Employees_for_each_month_5, 6: Number_of_Employees_for_each_month_6}

# %%
prob2 += lpSum([(6-i)*3300*0.9*Trained[i] for i in month[0:5]])\
      + 3000*Num[1]\
      + lpSum([3000*(Num[i] - sum(0.9*Trained[j] for j in month[0:i-1])) for i in month[1:6]])
prob2
# Out:
# Prob2:
# MINIMIZE
# 3000*Number_of_Employees_for_each_month_1 + 3000*Number_of_Employees_for_each_month_2 + 3000*Number_of_Employees_for_each_month_3 + 3000*Number_of_Employees_for_each_month_4 + 3000*Number_of_Employees_for_each_month_5 + 3000*Number_of_Employees_for_each_month_6 + 1350.0*Training_Decision_1 + 1080.0*Training_Decision_2 + 810.0*Training_Decision_3 + 540.0*Training_Decision_4 + 270.0*Training_Decision_5 + 0.0
# VARIABLES
# Number_of_Employees_for_each_month_1 Continuous
# Number_of_Employees_for_each_month_2 Continuous
# Number_of_Employees_for_each_month_3 Continuous
# Number_of_Employees_for_each_month_4 Continuous
# Number_of_Employees_for_each_month_5 Continuous
# Number_of_Employees_for_each_month_6 Continuous
# Training_Decision_1 Continuous
# Training_Decision_2 Continuous
# Training_Decision_3 Continuous
# Training_Decision_4 Continuous
# Training_Decision_5 Continuous

# %%
prob2 += Num[1] == 145
prob2 += Num[1] - Trained[1] >= 100,'Labor demand month 1'
prob2 += Num[6] + 0.2*0.9*(sum(Trained[j] for j in month[0:5])) >= Demand_per_mon[6],'Labor demand month 6'
for i in month[1:5]:
    prob2 += Num[i] - Trained[i] + 0.2*0.9*(sum(Trained[j] for j in month[0:i-1])) >= Demand_per_mon[i],'Labor demand month %s'%i

# Next month’s total employment = reduce the layoff amount 
for i in month[0:5]:
    prob2 += Num[i] - Layoff[i] == Num[i+1],'Inflow-outflow balance %s'%i
    
# Each month‘s layoff = 5% of (total employees - trained programmers - programmers on training)
prob2 += Layoff[1] == 0.05*(Num[1] - Trained[1]),'Layoff month 1'
for i in month[1:5]:
     prob2 += Layoff[i] == 0.05*(Num[i] - sum(Trained[j] for j in month[0:i])),'Layoff month %s'%i
prob2 += Layoff[6] == 0.05*(Num[6] - Trained[1] - Trained[2] - Trained[3] - Trained[4] - Trained[5]),'Layoff month 6'

    
# Each month’s # of trained programmers <= # of untrained programmers
for i in month[1:5]:
      prob2 += Trained[i] <= Num[i] - sum(Trained[j] for j in month[0:i-1]),'Train limit month %s'%i
prob2 += Trained[1] <= Num[1],'Train limit month 1'

# %%
prob2.solve()
print("Status:",LpStatus[prob2.status])
# Out:
# Status: Optimal

# %%
for i in prob2.variables():
    print(i.name, "=", i.varValue,"\tReduced Cost =", i.dj)
print("The minimize total operating cost for 6 months is ", value(prob2.objective))
# Out:
# Layoff_Decision_1 = 6.2163947 	Reduced Cost = 0.0
# Layoff_Decision_2 = 3.7803458 	Reduced Cost = 0.0
# Layoff_Decision_3 = 2.0225753 	Reduced Cost = 0.0
# Layoff_Decision_4 = 1.9214465 	Reduced Cost = -9.094947e-13
# Layoff_Decision_5 = 1.8253742 	Reduced Cost = -4.5474735e-13
# Layoff_Decision_6 = 1.7341055 	Reduced Cost = 0.0
# Number_of_Employees_for_each_month_1 = 145.0 	Reduced Cost = 1.1368684e-13
# Number_of_Employees_for_each_month_2 = 138.78361 	Reduced Cost = -7.1054274e-14
# Number_of_Employees_for_each_month_3 = 135.00326 	Reduced Cost = 7.1054274e-14
# Number_of_Employees_for_each_month_4 = 132.98068 	Reduced Cost = -8.5265128e-13
# Number_of_Employees_for_each_month_5 = 131.05924 	Reduced Cost = 5.6843419e-14
# Number_of_Employees_for_each_month_6 = 129.23386 	Reduced Cost = 9.094947e-13
# Training_Decision_1 = 20.672106 	Reduced Cost = -4.5474735e-13
# Training_Decision_2 = 42.504584 	Reduced Cost = 1.1368684e-13
# Training_Decision_3 = 31.375064 	Reduced Cost = 7.3896445e-13
# Training_Decision_4 = 0.0 	Reduced Cost = 10902.201
# Training_Decision_5 = 0.0 	Reduced Cost = 420.0
# The minimize total operating cost for 6 months is  2535408.0456600003

# %%
print("\nSensitivity Analysis\nConstraint\t\t\t\t\t\t\tShadow Price\t\tSlack")
for name,c in list(prob2.constraints.items()):
    print(name,":",c,"\t",c.pi,"\t\t",c.slack)
# Out:
# Sensitivity Analysis
# Constraint							Shadow Price		Slack
# _C1 : Number_of_Employees_for_each_month_1 = 145 	 6482.1193 		 -0.0
# Labor_demand_month_1 : Number_of_Employees_for_each_month_1 - Training_Decision_1 >= 100 	 0.0 		 -24.327889999999996
# Labor_demand_month_6 : Number_of_Employees_for_each_month_6 + 0.18000000000000002*Training_Decision_1 + 0.18000000000000002*Training_Decision_2 + 0.18000000000000002*Training_Decision_3 + 0.18000000000000002*Training_Decision_4 + 0.18000000000000002*Training_Decision_5 >= 125.0 	 0.0 		 -21.253179999999986
# Labor_demand_month_2 : Number_of_Employees_for_each_month_2 + 0.18000000000000002*Training_Decision_1 - Training_Decision_2 >= 100.0 	 384.12664 		 -0.0
# Labor_demand_month_3 : Number_of_Employees_for_each_month_3 + 0.18000000000000002*Training_Decision_1 + 0.18000000000000002*Training_Decision_2 - Training_Decision_3 >= 115.0 	 601.15618 		 -0.0
# Labor_demand_month_4 : Number_of_Employees_for_each_month_4 + 0.18000000000000002*Training_Decision_1 + 0.18000000000000002*Training_Decision_2 + 0.18000000000000002*Training_Decision_3 - Training_Decision_4 >= 150.0 	 9919.7008 		 -0.0
# Labor_demand_month_5 : Number_of_Employees_for_each_month_5 + 0.18000000000000002*Training_Decision_1 + 0.18000000000000002*Training_Decision_2 + 0.18000000000000002*Training_Decision_3 + 0.18000000000000002*Training_Decision_4 - Training_Decision_5 >= 140.0 	 0.0 		 -8.078550000000007
# Inflow_outflow_balance_1 : -Layoff_Decision_1 + Number_of_Employees_for_each_month_1 - Number_of_Employees_for_each_month_2 = 0 	 -3665.3888 		 -0.0
# Inflow_outflow_balance_2 : -Layoff_Decision_2 + Number_of_Employees_for_each_month_2 - Number_of_Employees_for_each_month_3 = 0 	 -1104.7531 		 -2.8421709e-14
# Inflow_outflow_balance_3 : -Layoff_Decision_3 + Number_of_Employees_for_each_month_3 - Number_of_Employees_for_each_month_4 = 0 	 1362.2008 		 -0.0
# Inflow_outflow_balance_4 : -Layoff_Decision_4 + Number_of_Employees_for_each_month_4 - Number_of_Employees_for_each_month_5 = 0 	 -5850.0 		 -2.8421709e-14
# Inflow_outflow_balance_5 : -Layoff_Decision_5 + Number_of_Employees_for_each_month_5 - Number_of_Employees_for_each_month_6 = 0 	 -3000.0 		 -0.0
# Layoff_month_1 : Layoff_Decision_1 - 0.05*Number_of_Employees_for_each_month_1 + 0.05*Training_Decision_1 = -0.0 	 -3665.3888 		 4.4408921e-16
# Layoff_month_2 : Layoff_Decision_2 - 0.05*Number_of_Employees_for_each_month_2 + 0.05*Training_Decision_1 + 0.05*Training_Decision_2 = -0.0 	 -1104.7531 		 -4.4408921e-16
# Layoff_month_3 : Layoff_Decision_3 - 0.05*Number_of_Employees_for_each_month_3 + 0.05*Training_Decision_1 + 0.05*Training_Decision_2 + 0.05*Training_Decision_3 = -0.0 	 1362.2008 		 -2.2870594e-14
# Layoff_month_4 : Layoff_Decision_4 - 0.05*Number_of_Employees_for_each_month_4 + 0.05*Training_Decision_1 + 0.05*Training_Decision_2 + 0.05*Training_Decision_3 + 0.05*Training_Decision_4 = -0.0 	 -5850.0 		 -6.6613381e-16
# Layoff_month_5 : Layoff_Decision_5 - 0.05*Number_of_Employees_for_each_month_5 + 0.05*Training_Decision_1 + 0.05*Training_Decision_2 + 0.05*Training_Decision_3 + 0.05*Training_Decision_4 + 0.05*Training_Decision_5 = -0.0 	 -3000.0 		 -6.6613381e-16
# Layoff_month_6 : Layoff_Decision_6 - 0.05*Number_of_Employees_for_each_month_6 + 0.05*Training_Decision_1 + 0.05*Training_Decision_2 + 0.05*Training_Decision_3 + 0.05*Training_Decision_4 + 0.05*Training_Decision_5 = -0.0 	 0.0 		 2.220446e-16
# Train_limit_month_2 : -Number_of_Employees_for_each_month_2 + Training_Decision_1 + Training_Decision_2 <= 0 	 0.0 		 75.606915
# Train_limit_month_3 : -Number_of_Employees_for_each_month_3 + Training_Decision_1 + Training_Decision_2 + Training_Decision_3 <= 0 	 0.0 		 40.451505
# Train_limit_month_4 : -Number_of_Employees_for_each_month_4 + Training_Decision_1 + Training_Decision_2 + Training_Decision_3 + Training_Decision_4 <= 0 	 0.0 		 38.42893
# Train_limit_month_5 : -Number_of_Employees_for_each_month_5 + Training_Decision_1 + Training_Decision_2 + Training_Decision_3 + Training_Decision_4 + Training_Decision_5 <= 0 	 0.0 		 36.507484
# Train_limit_month_1 : -Number_of_Employees_for_each_month_1 + Training_Decision_1 <= 0 	 0.0 		 124.32789

# %%
output=[]
for i in month:
    var_output=[]
    var_output.append(Trained[i].varValue)
    var_output.append(Layoff[i].varValue)
    var_output.append(Num[i].varValue)

    output.append(var_output)


#print(output)    
col_names=['Training','Layoff','number of employees']
month_names=['Month 1', 'Month 2', 'Month 3', 'Month 4', 'Month 5', 'Month 6']
output_df = pd.DataFrame(output,index=month_names, columns=col_names)

print("Total cost=", value(prob2.objective))
output_df## Format PuLP Output
# Out:
# Total cost= 2535408.0456600003
#           Training    Layoff  number of employees
# Month 1  20.672106  6.216395            145.00000
# Month 2  42.504584  3.780346            138.78361
# Month 3  31.375064  2.022575            135.00326
# Month 4   0.000000  1.921447            132.98068
# Month 5   0.000000  1.825374            131.05924
# Month 6        NaN  1.734106            129.23386

# %%
output=[]
constraint_name=[]
for name, c in list(prob2.constraints.items()):
    var_output = []
    # print(name)
    constraint_name.append(name)
    var_output.append(str(c))
    var_output.append(c.pi)
    var_output.append(c.slack)
    output.append(var_output)
# print(constraint_name)    
col_names = ["Constraints","Shadow Price","Slack"]
# output_df = pd.DataFrame(output, index=constraint_name, columns=col_names)
output_df = pd.DataFrame(output, index = constraint_name, columns = col_names)
output_df
# Out:
#                                                                 Constraints  \
# _C1                              Number_of_Employees_for_each_month_1 = 145
# Labor_demand_month_1      Number_of_Employees_for_each_month_1 - Trainin...
# Labor_demand_month_6      Number_of_Employees_for_each_month_6 + 0.18000...
# Labor_demand_month_2      Number_of_Employees_for_each_month_2 + 0.18000...
# Labor_demand_month_3      Number_of_Employees_for_each_month_3 + 0.18000...
# Labor_demand_month_4      Number_of_Employees_for_each_month_4 + 0.18000...
# Labor_demand_month_5      Number_of_Employees_for_each_month_5 + 0.18000...
# Inflow_outflow_balance_1  -Layoff_Decision_1 + Number_of_Employees_for_e...
# Inflow_outflow_balance_2  -Layoff_Decision_2 + Number_of_Employees_for_e...
# Inflow_outflow_balance_3  -Layoff_Decision_3 + Number_of_Employees_for_e...
# Inflow_outflow_balance_4  -Layoff_Decision_4 + Number_of_Employees_for_e...
# Inflow_outflow_balance_5  -Layoff_Decision_5 + Number_of_Employees_for_e...
# Layoff_month_1            Layoff_Decision_1 - 0.05*Number_of_Employees_f...
# Layoff_month_2            Layoff_Decision_2 - 0.05*Number_of_Employees_f...
# Layoff_month_3            Layoff_Decision_3 - 0.05*Number_of_Employees_f...
# Layoff_month_4            Layoff_Decision_4 - 0.05*Number_of_Employees_f...
# Layoff_month_5            Layoff_Decision_5 - 0.05*Number_of_Employees_f...
# Layoff_month_6            Layoff_Decision_6 - 0.05*Number_of_Employees_f...
# Train_limit_month_2       -Number_of_Employees_for_each_month_2 + Traini...
# Train_limit_month_3       -Number_of_Employees_for_each_month_3 + Traini...
# Train_limit_month_4       -Number_of_Employees_for_each_month_4 + Traini...
# Train_limit_month_5       -Number_of_Employees_for_each_month_5 + Traini...
# Train_limit_month_1       -Number_of_Employees_for_each_month_1 + Traini...
#
#                           Shadow Price         Slack
# _C1                         6482.11930 -0.000000e+00
# Labor_demand_month_1           0.00000 -2.432789e+01
# Labor_demand_month_6           0.00000 -2.125318e+01
# Labor_demand_month_2         384.12664 -0.000000e+00
# Labor_demand_month_3         601.15618 -0.000000e+00
# Labor_demand_month_4        9919.70080 -0.000000e+00
# Labor_demand_month_5           0.00000 -8.078550e+00
# Inflow_outflow_balance_1   -3665.38880 -0.000000e+00
# Inflow_outflow_balance_2   -1104.75310 -2.842171e-14
# Inflow_outflow_balance_3    1362.20080 -0.000000e+00
# Inflow_outflow_balance_4   -5850.00000 -2.842171e-14
# Inflow_outflow_balance_5   -3000.00000 -0.000000e+00
# Layoff_month_1             -3665.38880  4.440892e-16
# Layoff_month_2             -1104.75310 -4.440892e-16
# Layoff_month_3              1362.20080 -2.287059e-14
# Layoff_month_4             -5850.00000 -6.661338e-16
# Layoff_month_5             -3000.00000 -6.661338e-16
# Layoff_month_6                 0.00000  2.220446e-16
# Train_limit_month_2            0.00000  7.560692e+01
# Train_limit_month_3            0.00000  4.045150e+01
# Train_limit_month_4            0.00000  3.842893e+01
# Train_limit_month_5            0.00000  3.650748e+01
# Train_limit_month_1            0.00000  1.243279e+02
